# %% [markdown]
# This notebook is responsible for producing the YOLO model used to track the players.

# %%
from ultralytics import YOLO
import shutil

# The players will fall under the "Person" class
model = YOLO("yolov8x.pt")

# %%
shutil.move("yolov8x.pt", "../models/yolov8x_player_tracker.pt")
